# %% [markdown]
# # Importing Required Libraries

# %%
import cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# # **Loading & Displaying the Image**

# %%
image = cv2.imread("dog.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7F4EFF5E88D0>

# %% [markdown]
# # **Converting an Image into Gray Scale Image**

# %%
grayImage = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
cv2_imshow(grayImage)
# Out:
# <PIL.Image.Image image mode=L size=150x150 at 0x7F4EFF4FB0D0>

# %% [markdown]
# # **Inverting the Image**

# %%
invertImage = cv2.bitwise_not(grayImage)
cv2_imshow(invertImage)
# Out:
# <PIL.Image.Image image mode=L size=150x150 at 0x7F4EFF4FB990>

# %% [markdown]
# # **Smoothing the Image**

# %%
image_smoothing = cv2.GaussianBlur(invertImage, (21,21),sigmaX=0, sigmaY=0)
cv2_imshow(image_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=150x150 at 0x7F4EFF505490>

# %% [markdown]
# # **Obtaining the Final Image**

# %%
def dodgeV2(x,y):
  return cv2.divide(x,255-y, scale=256)

# %% [markdown]
# # **Final Output as Pencil Sketch**

# %%
final_image = dodgeV2(grayImage,image_smoothing)
cv2_imshow(final_image)
# Out:
# <PIL.Image.Image image mode=L size=150x150 at 0x7F4EFF50F450>

# %% [markdown]
# # **Initial Image -> Final Image**

# %%
cv2_imshow(image)
cv2_imshow(final_image)
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7F4EFF50FBD0>
# <PIL.Image.Image image mode=L size=150x150 at 0x7F4EFF50FBD0>
